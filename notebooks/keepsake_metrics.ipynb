# %%
import keepsake

# %%
experiments = keepsake.experiments.list()

# %%
len(experiments[0].checkpoints)
# Out:
# 12

# %%
experiments[0].best().metrics
# Out:
# {'sampled_num': 1200,
#  'total_true_r': 574,
#  'run_group': 'anxious aardvark',
#  'batch_size': 100,
#  'sampled_percentage': 0.06301528120569239,
#  'total_num': 19043,
#  'ap': 0.10944468024634443,
#  'metric_type': 'step',
#  'iteration': 12,
#  'running_true_recall': 0.4912891986062718,
#  'running_true_r': 282}

# %%
experiments.plot()
